# %% [markdown]
# #### All main Libraries

# %%
# !pip install -q qiskit-aer
# !pip install qiskit
# !pip install -q qiskit
# !pip install -q pylatexenc
# !pip install -q qiskit-ibmq-provider
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 12.4/12.4 MB 35.5 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.3/4.3 MB 49.5 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.0/2.0 MB 74.6 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 116.3/116.3 kB 9.4 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 49.7/49.7 kB 4.6 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 39.4/39.4 MB 13.8 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 107.5/107.5 kB 10.1 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 162.6/162.6 kB 1.3 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# ...

# %%
from qiskit import QuantumCircuit
from qiskit.quantum_info import Statevector
from qiskit import Aer, execute, BasicAer
from qiskit import QuantumCircuit, Aer, IBMQ, QuantumRegister, ClassicalRegister, execute
from qiskit.visualization import plot_state_qsphere, plot_histogram, plot_bloch_multivector
import numpy as np
from numpy import sqrt

# %% [markdown]
# ## Qubits / Single Qubit gates

# %%
ket_zero = np.array([1,0])
print(ket_zero)
# Out:
# [1 0]

# %%
plot_bloch_multivector(ket_zero)

# %%
ket_one = np.array([0,1])
plot_bloch_multivector(ket_one)

# %%
ket_plus = 1/sqrt(2)*(ket_zero + ket_one)
plot_bloch_multivector(ket_plus)

# %%
ket_minus = 1/sqrt(2)*(ket_zero - ket_one)
plot_bloch_multivector(ket_minus)

# %%
iota_plus = 1/sqrt(2)*(ket_zero + 1j * ket_one)
plot_bloch_multivector(iota_plus)

# %%
iota_minus = 1/sqrt(2)*(ket_zero - 1j * ket_one)
plot_bloch_multivector(iota_minus)

# %%
not_gate = np.array([[0,1],[1,0]])
print("Not gate : \n ",not_gate),print("\nKet Zero \n",ket_zero)
# Out:
# Not gate :
#   [[0 1]
#  [1 0]]
#
# Ket Zero
#  [1 0]
# (None, None)

# %%
# '@' is used for matrix multiplication
state_not = not_gate @ ket_zero
plot_bloch_multivector(state_not)

# %%
# '@' is used for matrix multiplication
state_one = not_gate @ ket_one
plot_bloch_multivector(state_one)

# %% [markdown]
# ## Hadmard Gate

# %%
hadmard_gate = 1/sqrt(2)*np.array([[1,1],[1,-1]])
print(hadmard_gate)
# Out:
# [[ 0.70710678  0.70710678]
#  [ 0.70710678 -0.70710678]]

# %%
H_state_zero = hadmard_gate @ ket_zero
plot_bloch_multivector(H_state_zero)

# %%
H_state_one = hadmard_gate @ ket_one
plot_bloch_multivector(H_state_one)

# %%
back_state = hadmard_gate @ H_state_one
plot_bloch_multivector(back_state)

# %% [markdown]
# ## How to make Quantum Circuits

# %%
qc = QuantumCircuit(1) # for one qubit circuit
qc.x(0)
qc.draw('mpl')

# %%
state_evolve = Statevector(qc)
print(state_evolve)
plot_bloch_multivector(state_evolve)
# Out:
# Statevector([0.+0.j, 1.+0.j],
#             dims=(2,))

# %%
qc.x(0)
qc.draw('mpl')
# Out:
# /usr/local/lib/python3.10/dist-packages/qiskit/visualization/circuit/matplotlib.py:266: FutureWarning: The default matplotlib drawer scheme will be changed to "iqp" in a following release. To silence this warning, specify the current default explicitly as style="clifford", or the new default as style="iqp".
#   self._style, def_font_ratio = load_style(self._style)

# %%
state_evolve2 = Statevector(qc)
print(state_evolve2)
plot_bloch_multivector(state_evolve2)
# Out:
# Statevector([1.+0.j, 0.+0.j],
#             dims=(2,))

# %%
qc2 = QuantumCircuit(1) # for one qubit circuit and two states
qc2.x(0)
qc2.h(0)
qc2.draw('mpl')

# %%
qc3 = QuantumCircuit(2) # for two qubit circuit
qc3.x(0)
qc3.h(1)
qc3.draw('mpl')

# %%
circuitH  = QuantumCircuit(1)
circuitH.h(0)
circuitH.draw('mpl')
# Out:
# /usr/local/lib/python3.10/dist-packages/qiskit/visualization/circuit/matplotlib.py:266: FutureWarning: The default matplotlib drawer scheme will be changed to "iqp" in a following release. To silence this warning, specify the current default explicitly as style="clifford", or the new default as style="iqp".
#   self._style, def_font_ratio = load_style(self._style)

# %%
h_state = Statevector(circuitH)
plot_bloch_multivector(h_state)

# %% [markdown]
# ## Bell State Generation

# %%
qc = QuantumCircuit(1,1) #single Qubit circut (1,#) 1 for quantum and 1 for # Classical Register
qc.h(0)   # Single Qubit Gate
qc.measure(0,0) # Applying on zeroth qubit
qc.draw('mpl')
# Out:
# /usr/local/lib/python3.10/dist-packages/qiskit/visualization/circuit/matplotlib.py:266: FutureWarning: The default matplotlib drawer scheme will be changed to "iqp" in a following release. To silence this warning, specify the current default explicitly as style="clifford", or the new default as style="iqp".
#   self._style, def_font_ratio = load_style(self._style)

# %%
## Running above circuit on Qunatum Simulator
simulator = Aer.get_backend('qasm_simulator')
result = execute(qc,simulator, shots = 200).result()
counts = result.get_counts(qc)
plot_histogram(counts)

# %%
BellC = QuantumCircuit(2,2)
BellC.h(0)
BellC.cx(0,1)
BellC.measure(0,0)
BellC.measure(1,1)
BellC.draw('mpl')
# Out:
# /usr/local/lib/python3.10/dist-packages/qiskit/visualization/circuit/matplotlib.py:266: FutureWarning: The default matplotlib drawer scheme will be changed to "iqp" in a following release. To silence this warning, specify the current default explicitly as style="clifford", or the new default as style="iqp".
#   self._style, def_font_ratio = load_style(self._style)

# %%
BellC2 = QuantumCircuit(2)
BellC2.h(0)
BellC2.cx(0,1)
BellC2.draw('mpl')
# Out:
# /usr/local/lib/python3.10/dist-packages/qiskit/visualization/circuit/matplotlib.py:266: FutureWarning: The default matplotlib drawer scheme will be changed to "iqp" in a following release. To silence this warning, specify the current default explicitly as style="clifford", or the new default as style="iqp".
#   self._style, def_font_ratio = load_style(self._style)

# %%
sv = Statevector.from_label('10')
plot_bloch_multivector(sv)

# %%
plot_state_qsphere(sv.data)

# %%
BellC = QuantumCircuit(2,2)
BellC.h(0)
BellC.cx(0,1)
BellC.measure(0,0)
BellC.measure(1,1)
BellC.draw('mpl')
# Out:
# /usr/local/lib/python3.10/dist-packages/qiskit/visualization/circuit/matplotlib.py:266: FutureWarning: The default matplotlib drawer scheme will be changed to "iqp" in a following release. To silence this warning, specify the current default explicitly as style="clifford", or the new default as style="iqp".
#   self._style, def_font_ratio = load_style(self._style)

# %%
simulator = Aer.get_backend('qasm_simulator')
result = execute(BellC,simulator, shots = 1000).result()
counts = result.get_counts(BellC)
plot_histogram(counts)

# %%
sv2 = Statevector.from_label('10')
plot_state_qsphere(sv2.data)

# %%
# def BellGenerator(q0,q1,shots = 1000):
#   BellC = QuantumCircuit(2,2)
#   BellC.h(q0)
#   BellC.cx(q0,q1)
#   BellC.measure(0,0)
#   BellC.measure(1,1)
#   BellC.draw('mpl')
#   simulator = Aer.get_backend('qasm_simulator')
#   result = execute(BellC,simulator, shots = shots).result()
#   counts = result.get_counts(BellC)
#   plot_histogram(counts)
#   return print("Bell State Generated Successfully!")

# %% [markdown]
# ## Teleportation (1st implementation)

# %%
# Creating the Teleportation Circuit
TPC = QuantumCircuit(3,1)
TPC.draw('mpl')
# Out:
# /usr/local/lib/python3.10/dist-packages/qiskit/visualization/circuit/matplotlib.py:266: FutureWarning: The default matplotlib drawer scheme will be changed to "iqp" in a following release. To silence this warning, specify the current default explicitly as style="clifford", or the new default as style="iqp".
#   self._style, def_font_ratio = load_style(self._style)

# %% [markdown]
# `**Defining a plus state**`

# %%
ket_zero = np.array([1,0])
ket_one = np.array([0,1])
ket_plus = 1/sqrt(2)*(ket_zero + ket_one)
plot_bloch_multivector(ket_plus)

# %%
TPC.initialize(ket_plus,0)
TPC.barrier() ## Putting barrier
TPC.draw('mpl')

# %%
# Creating a Function the draw the circuit whenever needed
def DC():
  return TPC.draw('mpl')

# %%
TPC.h(1)
TPC.cx(1,2)
TPC.barrier()
DC()

# %%
TPC.cx(0,1)
TPC.h(0)
TPC.barrier()
DC()

# %%
TPC.cx(1,2)
TPC.barrier()
TPC.h(2)
TPC.cx(0,2)
TPC.h(2)
DC()

# %%
## Adding measurement
TPC.barrier()
TPC.measure(2,0)
DC()

# %%
backend = Aer.get_backend('statevector_simulator')
backend_results_state = execute(TPC,backend).result().get_statevector()
plot_bloch_multivector(backend_results_state)

# %%
plot_state_qsphere(backend_results_state)

# %%
backend2 = Aer.get_backend('qasm_simulator')
backend_results_count = execute(TPC,backend,shots=1024).result().get_counts()
plot_histogram(backend_results_count)

# %% [markdown]
# ## Quantum Coin Game

# %%
# Function to Draw Circuit
def DC(circuit):
  circuit.barrier()
  return circuit.draw('mpl')

# %%
## Function to give Quantum Computer its Turn
def QuntumComp_Turn(QC):
  QC.h(0)
  return DC(QC)

# %%
## Function to give Human his Turn
def HumanTurn(QC):
  options=[('Identity', 'i'), ('Bit Flip', 'x')]
  print("select an option\n", options[0],'\n',options[1])
  opt = input("1 or 2 :")
  if opt == '1':
    QC.i(0)
  elif opt == '2':
    QC.x(0)
  else:
    print("Select correct input")
  return DC(QC)

# %%
## Creating a Circuit
QC = QuantumCircuit(1,1) # 1 for circuit type and 1 for measurement
DC(QC)
# Out:
# /usr/local/lib/python3.10/dist-packages/qiskit/visualization/circuit/matplotlib.py:266: FutureWarning: The default matplotlib drawer scheme will be changed to "iqp" in a following release. To silence this warning, specify the current default explicitly as style="clifford", or the new default as style="iqp".
#   self._style, def_font_ratio = load_style(self._style)

# %%
## 1st Qunatum Computers Turn
QuntumComp_Turn(QC)

# %%
## 2nd Human's Turn
HumanTurn(QC)
# Out:
# select an option
#  ('Identity', 'i')
#  ('Bit Flip', 'x')
# 1 or 2 :1
# <ipython-input-18-d04532b94657>:7: DeprecationWarning: The method ``qiskit.circuit.quantumcircuit.QuantumCircuit.i()`` is deprecated as of qiskit 0.45.0. It will be removed no earlier than 3 months after the release date. Use QuantumCircuit.id as direct replacement.
#   QC.i(0)

# %%
## 3rd Qunatum Computers Turn
QuntumComp_Turn(QC)

# %% [markdown]
# ### Measuring the Results

# %%
QC.measure(0,0)
DC(QC)

# %% [markdown]
# ### Checking the Results on Simulator and Qunatum Computer

# %%
from qiskit.visualization import plot_histogram
backend = Aer.get_backend('aer_simulator')
job = execute(QC, backend, shots=7000)
res = job.result().get_counts()
print(res)
plot_histogram(res)
# Out:
# {'0': 7000}

# %%
## Defining a Function to Check winner from the result
def checkwins(keys,length):
  if keys[0] == '0' and length == 1:
    print('Qunatum Computer wins the game')
  elif keys[1] == '1'and length == 1:
    print('Human Wins wins the game')
  else:
    print("It is Tie Match.")

# %%
## Checking the Results
## As  |0> is for the Qunatum Computer
## and |1> is for the Human so
keys = list(res.keys())
length = len(keys)
checkwins(keys,length)
# Out:
# Qunatum Computer wins the game

# %% [markdown]
# ### Running on Real Quantum Computer

# %%
from qiskit import IBMQ
IBMQ.save_account('e770c96c2144fc8bd127a731f2790fbffb2745c7f4a67cb55a1f9ba5f89cf962694a11e8fc1978036b41308042190e5d702945b2ad5db6bf29f637799a2a87c0')
provider = IBMQ.load_account()


def RunOnRealQC(QC):
  backend_real = provider.get_backend('simulator_stabilizer')
  job_real = execute(QC, backend_real, shots=500)
  res_real = job_real.result().get_counts()
  print(res_real)
  return plot_histogram(res_real)
# Out:
# <ipython-input-34-a190b0a3960b>:2: DeprecationWarning: The package qiskit.providers.ibmq is being deprecated. Please see https://ibm.biz/provider_migration_guide to get instructions on how to migrate to qiskit-ibm-provider (https://github.com/Qiskit/qiskit-ibm-provider) and qiskit-ibm-runtime (https://github.com/Qiskit/qiskit-ibm-runtime).
#   IBMQ.save_account('e770c96c2144fc8bd127a731f2790fbffb2745c7f4a67cb55a1f9ba5f89cf962694a11e8fc1978036b41308042190e5d702945b2ad5db6bf29f637799a2a87c0')
# <ipython-input-34-a190b0a3960b>:2: DeprecationWarning: The qiskit.IBMQ entrypoint and the qiskit-ibmq-provider package (accessible from 'qiskit.providers.ibmq`) are deprecated and will be removed in a future release. Instead you should use the qiskit-ibm-provider package which is accessible from 'qiskit_ibm_provider'. You can install it with 'pip install qiskit_ibm_provider'. Just replace 'qiskit.IBMQ' with 'qiskit_ibm_provider.IBMProvider'
# ...

# %%
RunOnRealQC(QC)
# Out:
# {'0': 500}

# %% [markdown]
# ### Q2: Part 1

# %%
QC2 = QuantumCircuit(1,1) # 1 for circuit type and 1 for measurement
DC(QC2)

# %%
## 1st Human's Turn
HumanTurn(QC2)
# Out:
# select an option
#  ('Identity', 'i')
#  ('Bit Flip', 'x')
# 1 or 2 :1
# <ipython-input-18-d04532b94657>:7: DeprecationWarning: The method ``qiskit.circuit.quantumcircuit.QuantumCircuit.i()`` is deprecated as of qiskit 0.45.0. It will be removed no earlier than 3 months after the release date. Use QuantumCircuit.id as direct replacement.
#   QC.i(0)

# %%
## 2nd Qunatum Computers Turn
QuntumComp_Turn(QC2)

# %%
## 3rd Human's Turn
HumanTurn(QC2)
# Out:
# select an option
#  ('Identity', 'i')
#  ('Bit Flip', 'x')
# 1 or 2 :2

# %%
QC2.measure(0,0)
DC(QC2)

# %%
backend2 = Aer.get_backend('aer_simulator')
job2 = execute(QC2, backend2, shots=7000)
res2 = job2.result().get_counts()
print(res2)
plot_histogram(res2)
# Out:
# {'0': 3544, '1': 3456}

# %%
RunOnRealQC(QC2)
# Out:
# {'1': 267, '0': 233}

# %%
keys2 = list(res2.keys())
length2 = len(keys2)
checkwins(keys2,length2)
# Out:
# It is Tie Match.

# %% [markdown]
# ### Q2: Part 2

# %%
## Defining a New Function where changing the values
## as per question's requirements
## What if, instead of representing head as |0⟩, the tail is represented as |0⟩ ?
def checkwinsP2(keys,length):
  if keys[0] == '0' and length == 1:
    print('Human Wins wins the game')
  elif keys[1] == '1'and length == 1:
    print('Qunatum Computer wins the game')
  else:
    print("It is Tie Match.")

# %%
## Now checking the results from the Previous Circuit by above Function
checkwinsP2(keys,length)
# Out:
# Human Wins wins the game

# %% [markdown]
# ####**Now Human will win All the time**

# %% [markdown]
# ### Q2: Part 3

# %%
QC3 = QuantumCircuit(1,1) # 1 for circuit type and 1 for measurement
DC(QC3)
# Out:
# /usr/local/lib/python3.10/dist-packages/qiskit/visualization/circuit/matplotlib.py:266: FutureWarning: The default matplotlib drawer scheme will be changed to "iqp" in a following release. To silence this warning, specify the current default explicitly as style="clifford", or the new default as style="iqp".
#   self._style, def_font_ratio = load_style(self._style)

# %%
## 1st Qunatum Computers Turn
QuntumComp_Turn(QC3)

# %%
## 2nd Qunatum Computers Turn
QuntumComp_Turn(QC3)

# %%
## 3rd Qunatum Computers Turn
QuntumComp_Turn(QC3)

# %%
QC3.measure(0,0)
DC(QC3)

# %%
# Measuring the Result
backend3 = Aer.get_backend('aer_simulator')
job3 = execute(QC3, backend3, shots=7000)
res3 = job3.result().get_counts()
print(res3)
plot_histogram(res3)
# Out:
# {'0': 3384, '1': 3616}

# %%
keys3 = list(res3.keys())
length3 = len(keys3)
checkwins(keys3,length3)
# Out:
# It is Tie Match.

# %%
RunOnRealQC(QC3)
# Out:
# {'1': 243, '0': 257}

# %% [markdown]
# #### **If Two Quantum Computer plays together it will be Always a Tie game between both Computers.**

# %% [markdown]
# ## Teleportation (2nd implementation)

# %%
# Creating the Teleportation Circuit
TPC = QuantumCircuit(3,1)
TPC.draw('mpl')
# Out:
# /usr/local/lib/python3.10/dist-packages/qiskit/visualization/circuit/matplotlib.py:266: FutureWarning: The default matplotlib drawer scheme will be changed to "iqp" in a following release. To silence this warning, specify the current default explicitly as style="clifford", or the new default as style="iqp".
#   self._style, def_font_ratio = load_style(self._style)

# %%
ket_zero = np.array([1,0])
ket_one = np.array([0,1])
ket_plus = 1/sqrt(2)*(ket_zero + ket_one)
plot_bloch_multivector(ket_plus)

# %%
TPC.initialize(ket_plus,0)
TPC.barrier() ## Putting barrier
TPC.draw('mpl')

# %%
# Creating a Function the draw the circuit whenever needed
def DC():
  return TPC.draw('mpl')

# %%
TPC.h(1)
TPC.cx(1,2)
TPC.barrier()
DC()

# %%
TPC.cx(0,1)
TPC.h(0)
TPC.barrier()
DC()

# %%
TPC.cx(1,2)
TPC.barrier()
TPC.h(2)
TPC.cx(0,2)
TPC.h(2)
DC()

# %%
## Adding measurement
TPC.barrier()
TPC.measure(2,0)
DC()

# %%
backend = Aer.get_backend('statevector_simulator')
backend_results_state = execute(TPC,backend).result().get_statevector()
plot_bloch_multivector(backend_results_state)

# %%
plot_state_qsphere(backend_results_state)

# %%
backend2 = Aer.get_backend('qasm_simulator')
backend_results_count = execute(TPC,backend,shots=1024).result().get_counts()
plot_histogram(backend_results_count)

# %% [markdown]
# ## DJ Algorithm

# %%
n =3
forallx = QuantumCircuit(n+1)
forallx.draw('mpl')
# Out:
# /usr/local/lib/python3.10/dist-packages/qiskit/visualization/circuit/matplotlib.py:266: FutureWarning: The default matplotlib drawer scheme will be changed to "iqp" in a following release. To silence this warning, specify the current default explicitly as style="clifford", or the new default as style="iqp".
#   self._style, def_font_ratio = load_style(self._style)

# %%
forallx = QuantumCircuit(n+1)
forallx.x(n)
forallx.draw('mpl')

# %%
forhalf= QuantumCircuit(n+1)
xgates = '101'
# cgates = '101'
forhalf.draw('mpl')

# %%
cxgates = '101'

# %%
for i in range(n):
  if xgates[i] == '1':
    ind = [i]
    forhalf.x(ind)

forhalf.draw('mpl')
# Out:
# /usr/local/lib/python3.10/dist-packages/qiskit/visualization/circuit/matplotlib.py:266: FutureWarning: The default matplotlib drawer scheme will be changed to "iqp" in a following release. To silence this warning, specify the current default explicitly as style="clifford", or the new default as style="iqp".
#   self._style, def_font_ratio = load_style(self._style)

# %%
for m in range(n):
  if cxgates[m] == '1':
    forhalf.cx(m,n)
forhalf.draw('mpl')
# Out:
# /usr/local/lib/python3.10/dist-packages/qiskit/visualization/circuit/matplotlib.py:266: FutureWarning: The default matplotlib drawer scheme will be changed to "iqp" in a following release. To silence this warning, specify the current default explicitly as style="clifford", or the new default as style="iqp".
#   self._style, def_font_ratio = load_style(self._style)

# %%
for i in range(n):
  if xgates[i] == '1':
    ind = [i]
    forhalf.x(ind)

forhalf.draw('mpl')

# %%
DJC = QuantumCircuit(n+1,n)

# %%
for qubit in range(n):
  DJC.h(qubit)
DJC.x(n)
DJC.h(n)
DJC.barrier()
DJC.draw('mpl')

# %%
DJC.barrier()
DJC.draw('mpl')

# %%
DJC = DJC.compose(forhalf)
DJC.barrier
DJC.draw('mpl')

# %%
for qubit in range(n):
  DJC.h(qubit)
DJC.barrier()
DJC.draw('mpl')

# %%
for i in range(n):
  DJC.measure(i,i)
DJC.barrier()
DJC.draw('mpl')

# %%
backend = Aer.get_backend('statevector_simulator')
# backend = BasicAer.get_backend('qasm_simulator')

# %%
backend_results_state = execute(DJC,backend).result().get_statevector()

# %%
plot_bloch_multivector(backend_results_state)

# %%
backend_results_count = execute(DJC,backend,shots=1024).result().get_counts()

# %%
plot_histogram(backend_results_count)

# %% [markdown]
# # Final Exam

# %% [markdown]
# ## Y Gate Circuit

# %%
# Function to Draw Circuit
def DC(circuit):
  circuit.barrier()
  return circuit.draw('mpl')

# %%
# Creating the A CIRCUIT to see normal behaviour of Y gate
YC = QuantumCircuit(1)
DC(YC)

# %%
# Applying Y gate
YC.y(0)
DC(YC)

# %%
backend = Aer.get_backend('statevector_simulator')
backend_results_state = execute(YC,backend).result().get_statevector()
print("Ploting on Bloch Multi vector")
plot_bloch_multivector(backend_results_state)
# Out:
# Ploting on Bloch Multi vector

# %%
print("Beckend State Result")
plot_state_qsphere(backend_results_state)
# Out:
# Beckend State Result

# %%
backend_results_count = execute(YC,backend,shots=1024).result().get_counts()
print("Printing Histogram")
plot_histogram(backend_results_count)
# Out:
# Printing Histogram

# %% [markdown]
# ### Combitional Gates for Y using S and H gates
# After doing multiple expeeriments I have reached to find a equivalent gate of Y in combinations of S and H

# %%
from qiskit import QuantumCircuit, Aer, transpile, assemble
from qiskit.visualization import plot_bloch_multivector
SHC = QuantumCircuit(1) #SH Circuit
DC(SHC)
# Out:
# /usr/local/lib/python3.10/dist-packages/qiskit/visualization/circuit/matplotlib.py:266: FutureWarning: The default matplotlib drawer scheme will be changed to "iqp" in a following release. To silence this warning, specify the current default explicitly as style="clifford", or the new default as style="iqp".
#   self._style, def_font_ratio = load_style(self._style)

# %%
# The equivalent of Y is
# Y = SHSSHS
# So implementing Circuits
SHC.s(0)
SHC.h(0)
SHC.s(0)
SHC.s(0)
SHC.h(0)
SHC.s(0)

DC(SHC)
# Out:
# /usr/local/lib/python3.10/dist-packages/qiskit/visualization/circuit/matplotlib.py:266: FutureWarning: The default matplotlib drawer scheme will be changed to "iqp" in a following release. To silence this warning, specify the current default explicitly as style="clifford", or the new default as style="iqp".
#   self._style, def_font_ratio = load_style(self._style)

# %%
backend = Aer.get_backend('statevector_simulator')
backend_results_state = execute(SHC,backend).result().get_statevector()
print("Ploting on Bloch Multi vector")
plot_bloch_multivector(backend_results_state)
# Out:
# Ploting on Bloch Multi vector

# %%
print("Beckend State Result")
plot_state_qsphere(backend_results_state)
# Out:
# Beckend State Result

# %%
backend_results_count = execute(SHC,backend,shots=1024).result().get_counts()
print("Printing Histogram")
plot_histogram(backend_results_count)
# Out:
# Printing Histogram

# %% [markdown]
# Both Y and SH-Combinational gate gives same output

# %% [markdown]
# ## Groover's Algorithm for n Searches

# %%
# Preparing all inputs in Super position State
def superposition(qc, qubits):
    """Apply a Hadamard gate to all qubits to create an equal superposition"""
    for q in qubits:
        qc.h(q)
    return qc

# %%
## Function for Phase oracle
def grover_oracle(qc, target_qubit, oracle_qubits):
    qc.x(target_qubit)
    qc.h(target_qubit)
    qc.mct(oracle_qubits, target_qubit)  # Toffoli gate
    qc.h(target_qubit)
    qc.x(target_qubit)
    return qc

# %%
## Function for Diffuser
def grover_diffusion(qc, qubits):
    qc.h(qubits)
    qc.x(qubits)
    qc.h(qubits[-1])
    qc.mct(qubits[:-1], qubits[-1])  # Multi-Controlled Toffoli gate
    qc.h(qubits[-1])
    qc.x(qubits)
    qc.h(qubits)
    return qc

# %%
## Groover's Main Function
def grover_algorithm(n, oracle_qubits, num_iterations):
    # Create quantum circuit
    qc = QuantumCircuit(n + 1, n)
    # Initialize qubits
    qc = superposition(qc, range(n + 1))
    # Grover iterations
    for _ in range(num_iterations):
        qc = grover_oracle(qc, n, oracle_qubits)
        qc = grover_diffusion(qc, range(n))
    # Measure the first n qubits
    qc.measure(range(n), range(n))
    return qc

# %%
qubits = int(input("Enter the number of qubits to genratate Phase Oracle: "))
targetbit = int(input("Enter the target bit "))
num_iterations = int(input("Enter number of iterations "))
# Converting target bits in in Binary
oracle_qubits = [i for i in range(qubits) if (targetbit & (1 << i)) != 0]
# Out:
# Enter the number of qubits to genratate Phase Oracle: 4
# Enter the target bit 12
# Enter number of iterations 4

# %%
# Create the Grover's Algorithm circuit
grover_circuit = grover_algorithm(qubits, oracle_qubits, num_iterations)
# Out:
# <ipython-input-48-c8707e177aa3>:5: DeprecationWarning: The method ``qiskit.circuit.quantumcircuit.QuantumCircuit.mct()`` is deprecated as of qiskit 0.45.0. It will be removed no earlier than 3 months after the release date. Use QuantumCircuit.mcx as direct replacement.
#   qc.mct(oracle_qubits, target_qubit)  # Toffoli gate
# <ipython-input-45-c632346d1c55>:25: DeprecationWarning: The method ``qiskit.circuit.quantumcircuit.QuantumCircuit.mct()`` is deprecated as of qiskit 0.45.0. It will be removed no earlier than 3 months after the release date. Use QuantumCircuit.mcx as direct replacement.
#   qc.mct(qubits[:-1], qubits[-1])  # Multi-Controlled Toffoli gate
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-50-382756e107a4> in <cell line: 2>()
#       1 # Create the Grover's Algorithm circuit
# ...

# %%
backend = Aer.get_backend('statevector_simulator')
backend_results_state = execute(SHC,backend).result().get_statevector()
print("Ploting on Bloch Multi vector")
plot_bloch_multivector(backend_results_state)

# %%
print("Beckend State Result")
plot_state_qsphere(backend_results_state)

# %%
backend_results_count = execute(SHC,backend,shots=1024).result().get_counts()
print("Printing Histogram")
plot_histogram(backend_results_count)

# %% [markdown]
# ## Quantum Fourirer Transform
#
# source : https://github.com/paramrathour/Quantum-Computing

# %% [markdown]
# #### Defining Major Functions

# %%
# Function for SWap Regisers
def Qswap(circuit,registers):
  for q in range(registers//2):  # Iterating a loop to swap values of qubits
    circuit.swap(q, registers-q-1) ## It will swap q value with n-1 qubit
    return circuit  ## return Circuit

# %%
## Function for Q Rotations
def Qrotations(circuit, registers):
    if registers == 0:   ## Checking the conditions if number of qubit are zero
        return circuit
    registers -= 1  # Subtracting 1 values from the qubits values as we will apply n-1 rotations
    circuit.h(registers)
    for qubit in range(registers):
        circuit.cp(np.pi/2**(registers-qubit), qubit, registers)  ## Applyying rotations iterativly between all n-1 qubits
    Qrotations(circuit,registers)    ## Recuersivly call rotations function to apply after each hadmard is applied

# %%
## Function for Qunatum Fourier Transform
def QFT(circuit, registers):
    """QFT on the first n qubits in circuit"""
    Qrotations(circuit, registers)   ## Calling the rotation Function to Apply rotations
    Qswap(circuit, registers) ## At Last Applying Swap Gate
    return circuit #Returning the Circuit

# %% [markdown]
# ##### Implementing QFT for for qubits

# %%
## Getting user's input to generate QFT circuit
qubits = int(input("Enter the number of qubit to generate QFT circuit : "))
QC = QuantumCircuit(qubits,qubits)  ## Generating a Circuit based on input
QFT(QC,qubits)  ## Calling QFT to apply QFT operations on the Circuit
QC.draw(output = 'mpl') ## Drawing the Circuit
# Out:
# Enter the number of qubit to generate QFT circuit : 5
# /usr/local/lib/python3.10/dist-packages/qiskit/visualization/circuit/matplotlib.py:266: FutureWarning: The default matplotlib drawer scheme will be changed to "iqp" in a following release. To silence this warning, specify the current default explicitly as style="clifford", or the new default as style="iqp".
#   self._style, def_font_ratio = load_style(self._style)

# %%
from qiskit import QuantumCircuit, Aer, transpile, assemble
from qiskit.visualization import plot_histogram
import numpy as np

def initialize_s(qc, qubits):
    """Apply a Hadamard gate to all qubits to create an equal superposition"""
    for q in qubits:
        qc.h(q)
    return qc

def grover_oracle(qc, target_qubit, oracle_qubits):
    """Apply the Grover Oracle to mark the solution"""
    qc.x(target_qubit)
    qc.h(target_qubit)
    qc.mct(oracle_qubits, target_qubit)  # Multi-Controlled Toffoli gate
    qc.h(target_qubit)
    qc.x(target_qubit)
    return qc

def grover_diffusion(qc, qubits):
    """Apply the Grover Diffusion Operator"""
    qc.h(qubits)
    qc.x(qubits)
    qc.h(qubits[-1])
    qc.mct(qubits[:-1], qubits[-1])  # Multi-Controlled Toffoli gate
    qc.h(qubits[-1])
    qc.x(qubits)
    qc.h(qubits)
    return qc

def grover_algorithm(n, oracle_qubits, num_iterations):
    """Grover's Algorithm"""
    # Create quantum circuit
    qc = QuantumCircuit(n + 1, n)

    # Initialize qubits
    qc = initialize_s(qc, range(n + 1))

    # Grover iterations
    for _ in range(num_iterations):
        qc = grover_oracle(qc, n, oracle_qubits)
        qc = grover_diffusion(qc, range(n))

    # Measure the first n qubits
    qc.measure(range(n), range(n))

    return qc

# Set the number of qubits and the oracle solution
n = 3  # Number of qubits
oracle_solution = 5  # Binary representation of the solution

# Create the oracle qubits as a list of indices where the solution is 1
oracle_qubits = [i for i in range(n) if (oracle_solution & (1 << i)) != 0]

# Set the number of iterations (empirically, around pi/4 * sqrt(2^n) iterations are often effective)
num_iterations = 2

# Create the Grover's Algorithm circuit
grover_circuit = grover_algorithm(n, oracle_qubits, num_iterations)

# Simulate the circuit
simulator = Aer.get_backend('qasm_simulator')
compiled_circuit = transpile(grover_circuit, simulator)
result = simulator.run(compiled_circuit, shots=10000).result()

# Display the results
counts = result.get_counts()
plot_histogram(counts)

# %% [markdown]
# ## New start here
